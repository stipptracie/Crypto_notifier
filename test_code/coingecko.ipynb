# %%
import pandas as pd
import requests
import os
import datetime
import time
import json

# %%
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

# %%
# Create from date
start_date = datetime.datetime(2021, 7, 26, 4, 0)
unix_start = time.mktime(start_date.timetuple())
print(unix_start)
# Out:
# 1627297200.0

# %%
# Create end date
end_date = datetime.datetime(2021, 7, 30, 4, 0)
unix_end = time.mktime(end_date.timetuple())
print(unix_end)
# Out:
# 1627642800.0

# %%
cg.get_coin_market_chart_range_by_id('bitcoin','usd', start_date, end_date)
# Out:
# {'prices': [], 'market_caps': [], 'total_volumes': []}

# %%
url = 'https://api.coingecko.com/api/v3/coins/bitcoin/market_chart/range?vs_currency=usd&from=1627297200&to=1627642800'

# %%
response = requests.get(url).json()
print(json.dumps(response, indent=2, sort_keys=True))
# Out:
# {
#   "market_caps": [
#     [
#       1627297318275,
#       722607838467.6454
#     ],
#     [
#       1627300803222,
#       722028540140.1364
#     ],
#     [
#       1627304514320,
#       726300563211.9984
#     ],
#     [
#       1627308025111,
#       720583929997.6495
#     ],
#     [
#       1627311741179,
#       719023603929.4657
#     ],
#     [
#       1627315278319,
#       724985032029.1024
#     ],
#     [
#       1627318859280,
#       735071750429.9723
#     ],
#     [
#       1627322579119,
#       736644819963.804
#     ],
#     [
#       1627326130343,
#       747538939197.5043
#     ],
#     [
#       1627329679842,
#       743297629317.7163
#     ],
#     [
#       1627333270433,
#       743297629317.7163
#     ],
#     [
#       1627336892558,
#       698746226547.2186
#     ],
#     [
#       1627340474993,
#       701782668309.3649
#     ],
#     [
#       1627344137670,
#       698654120074.028
#     ],
#     [
#       1627347730286,
# ...
